# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case['task']}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """
    
    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average Score: {average_score:.2f}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average Score: 7.33

# %%
print(json.dumps(results, indent=2  ))
# Out:
# [
#   {
#     "output": "# AWS Region Extractor from S3 URL\n\nHere's a Python function that extracts the AWS region from an S3 bucket URL:\n\n```python\nimport re\nfrom typing import Optional\n\ndef extract_aws_region(s3_url: str) -> Optional[str]:\n    \"\"\"\n    Extract AWS region from an S3 bucket URL.\n    \n    Supports multiple S3 URL formats:\n    - Virtual-hosted-style: s3://my-bucket.s3.us-west-2.amazonaws.com/key\n    - Path-style: s3://s3.us-west-2.amazonaws.com/my-bucket/key\n    - S3 URI: s3://my-bucket/key (returns None - no region info)\n    \n    Args:\n        s3_url: S3 bucket URL string\n        \n    Returns:\n        Region code (e.g., 'us-west-2') or None if region cannot be extracted\n    \"\"\"\n    # Pattern for virtual-hosted-style: bucket.s3.region.amazonaws.com\n    pattern1 = r'\\.s3[.-]([a-z0-9\\-]+)\\.amazonaws\\.com'\n    \n    # Pattern for path-style: s3.region.amazonaws.com\n    pattern2 = r's3[.-]([a-z0-9\\-]+)\\.amazonaws\\.com'\n    \n    # Try virtual-hosted-style first (more specific)\n    match = re.search(pattern1, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Try path-style\n    match = re.search(pattern2, s3_url)\n    if match:\n        return match.group(1)\n    \n    return None\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_urls = [\n        \"s3://my-bucket.s3.us-west-2.amazonaws.com/key\",\n        \"https://my-bucket.s3.eu-west-1.amazonaws.com/path/to/file\",\n        \"s3://s3.ap-southeast-1.amazonaws.com/my-bucket/key\",\n        \"https://s3.us-east-1.amazonaws.com/my-bucket/object\",\n        \"s3://my-bucket/key\",  # No region info\n        \"s3://my-bucket.s3.amazonaws.com/key\",  # US-east-1 (default, no region in URL)\n        \"s3://data-bucket.s3-ca-central-1.amazonaws.com/file.txt\",\n    ]\n    \n    for url in test_urls:\n        region = extract_aws_region(url)\n        print(f\"URL: {url}\")\n        print(f\"Region: {region}\\n\")\n```\n\n**Output:**\n```\nURL: s3://my-bucket.s3.us-west-2.amazonaws.com/key\nRegion: us-west-2\n\nURL: https://my-bucket.s3.eu-west-1.amazonaws.com/path/to/file\nRegion: eu-west-1\n\nURL: s3://s3.ap-southeast-1.amazonaws.com/my-bucket/key\nRegion: ap-southeast-1\n\nURL: https://s3.us-east-1.amazonaws.com/my-bucket/object\nRegion: us-east-1\n\nURL: s3://my-bucket/key\nRegion: None\n\nURL: s3://my-bucket.s3.amazonaws.com/key\nRegion: None\n\nURL: s3://data-bucket.s3-ca-central-1.amazonaws.com/file.txt\nRegion: ca-central-1\n```\n\n## Key Features:\n\n1. **Supports multiple S3 URL formats:**\n   - Virtual-hosted-style: `bucket.s3.region.amazonaws.com`\n   - Path-style: `s3.region.amazonaws.com/bucket`\n   - Both dot and dash notation: `s3.region` and `s3-region`\n\n2. **Returns `None`** when no region information is present in the URL\n\n3. **Uses regex patterns** to match AWS region codes (alphanumeric with hyphens)\n\n4",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URL like 's3://my-bucket.s3.us-west-2.amazonaws.com/key'. Return the region code."
#     },
#     "score": 8,
#     "reasoning": "The solution correctly solves the primary task and demonstrates good software engineering practices with type hints and documentation. The regex approach is sound and handles the main S3 URL formats well. However, the regex patterns could be more precise to avoid potential overlaps, and basic input validation would improve robustness. The test cases are comprehensive but could benefit from one additional edge case validation. Overall, this is a solid, production-ready solution with minor refinements needed for perfect implementation."
#   },
#   {
#     "output": "# AWS IAM S3 Read-Only Policy\n\nHere's a JSON object representing an AWS IAM policy for read-only access to the 'company-data' S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3BucketReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::company-data\",\n        \"arn:aws:s3:::company-data/*\"\n      ]\n    }\n  ]\n}\n```\n\n## Field Explanations:\n\n| Field | Description |\n|-------|-------------|\n| **Version** | Policy language version (standard: \"2012-10-17\") |\n| **Sid** | Statement ID - optional but recommended for clarity |\n| **Effect** | \"Allow\" grants permissions; \"Deny\" would restrict access |\n| **Action** | Specific S3 operations allowed:<br>- `s3:ListBucket` - List bucket contents<br>- `s3:GetObject` - Read object contents<br>- `s3:GetObjectVersion` - Read object versions |\n| **Resource** | ARNs specifying which resources the policy applies to:<br>- `arn:aws:s3:::company-data` - Bucket itself<br>- `arn:aws:s3:::company-data/*` - All objects in bucket |\n\n## Usage:\n\nAttach this policy to an IAM user, role, or group to grant them read-only access to the 'company-data' bucket.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'company-data'. Include the necessary Effect, Action, and Resource fields."
#     },
#     "score": 8,
#     "reasoning": "The solution correctly addresses the core task requirements with valid JSON syntax, appropriate IAM actions, and correct Resource ARNs. The documentation is comprehensive and helpful. However, the inclusion of GetObjectVersion without justification represents a minor over-permissioning issue. The solution is production-ready but could be more precise about scope and provide more complete guidance on implementation and validation."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the correct regular expression for matching valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n- `^` - Start of string\n- `i-` - Literal prefix \"i-\"\n- `[0-9a-f]{17}` - Exactly 17 hexadecimal characters (0-9 and a-f)\n- `$` - End of string\n\n## Examples\n\n### Valid matches:\n```\ni-0a1b2c3d4e5f6g7h8  \u274c (contains 'g' and 'h', not hex)\ni-0a1b2c3d4e5f67890  \u2705 (17 valid hex chars)\ni-1234567890abcdef0  \u2705 (17 valid hex chars)\ni-aaaaaaaaaaaaaaaaa  \u2705 (17 valid hex chars)\n```\n\n### Invalid matches:\n```\n0a1b2c3d4e5f67890   \u274c (missing 'i-' prefix)\ni-0a1b2c3d4e5f6789  \u274c (only 16 hex chars)\ni-0a1b2c3d4e5f678901 \u274c (18 hex chars - too long)\ni-0g1h2i3j4k5l6m7n8 \u274c (contains non-hex characters)\n```\n\n## Implementation Examples\n\n**JavaScript:**\n```javascript\nconst regex = /^i-[0-9a-f]{17}$/;\nconsole.log(regex.test('i-0a1b2c3d4e5f67890')); // true\n```\n\n**Python:**\n```python\nimport re\nregex = r'^i-[0-9a-f]{17}$'\nprint(re.match(regex, 'i-0a1b2c3d4e5f67890'))  # Match object\n```\n\n**Note:** If you want to make it case-insensitive (match uppercase too), add the `i` flag:\n```regex\n^i-[0-9a-fA-F]{17}$\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs. Valid instance IDs follow the format 'i-' followed by 17 hexadecimal characters (e.g., 'i-0a1b2c3d4e5f6g7h8')."
#     },
#     "score": 6,
#     "reasoning": "The regex solution is fundamentally sound and would work correctly in practice. However, the presentation is undermined by a significant labeling error in the examples section where an invalid instance ID is marked as valid. This creates confusion and reduces confidence in the solution, even though the actual regex pattern and most of the supporting information are accurate. The solution would have been stronger by catching the error in the original task description."
#   }
# ]
